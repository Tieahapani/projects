# %%
from sklearn.datasets import load_iris
# %matplotlib inline
import matplotlib.pyplot as plt
iris = load_iris()

# %%
print(iris.data)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
plt.matshow(iris.images, cmap='viridis') # Changed code
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_bunch.py in __getattr__(self, key)
#      56         try:
# ---> 57             return self[key]
#      58         except KeyError:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_bunch.py in __getitem__(self, key)
#      41             )
# ---> 42         return super().__getitem__(key)
#      43
#
# KeyError: 'images'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-00b41d398d93> in <cell line: 0>()
# ----> 1 plt.matshow(iris.images, cmap='viridis') # Changed code
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_bunch.py in __getattr__(self, key)
#      57             return self[key]
#      58         except KeyError:
# ...

# %%
plt.matshow(iris.data, cmap='viridis') # Changed 'images' to 'data'
plt.colorbar() # Adding a colorbar for better visualization
plt.show() # Displaying the plot

# %%
from sklearn.datasets import load_iris
import pandas as pd
iris = load_iris()
data = pd.DataFrame(data = iris.data, columns = iris.feature_names)
data['species'] = iris.target
data['species'] = data['species'].map({0:'setosa', 1:'versicolor', 2:'virginca'})
print(data.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = data.corr()
plt.figure(figsize = (8,6))
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', fmt= ".2f", linewidths = 0.5)
plt.title("Feature Correlation Heatmap")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-8f11025ec0ef> in <cell line: 0>()
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 correlation_matrix = data.corr()
#       4 plt.figure(figsize = (8,6))
#       5 sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', fmt= ".2f", linewidths = 0.5)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation only for numeric columns
correlation_matrix = data.select_dtypes(include=['number']).corr()

plt.figure(figsize = (8,6))
sns.heatmap(correlation_matrix, annot = True, cmap = 'coolwarm', fmt= ".2f", linewidths = 0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x = data['sepal lenght, sepal width, petal lenght, petal width']
y = data['species']
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal lenght, sepal width, petal lenght, petal width'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e185c5c6d131> in <cell line: 0>()
# ...

# %%
from sklearn.model_selection import train_test_split

# Access the columns individually by their names
x = data[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']]
y = data['species']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
predictions = model.predict(X_test)
print(predictions[:5])
# Out:
# ['versicolor' 'setosa' 'virginca' 'versicolor' 'versicolor']

# %%
from sklearn.metrics import accuracy_score, classification_report

# Example true labels (replace with actual values from your dataset)
true_labels = ['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor']

# Model predictions
predictions = ['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor']

# Check accuracy
accuracy = accuracy_score(true_labels, predictions)
print("Accuracy:", accuracy)

# Detailed performance report
print(classification_report(true_labels, predictions))
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         1
#   versicolor       1.00      1.00      1.00         3
#    virginica       1.00      1.00      1.00         1
#
#     accuracy                           1.00         5
#    macro avg       1.00      1.00      1.00         5
# weighted avg       1.00      1.00      1.00         5

# %%
print("Actual values:", y_test)
print("Predicted values:", y_pred)
# Out:
# Actual values: 73     versicolor
# 18         setosa
# 118      virginca
# 78     versicolor
# 76     versicolor
# 31         setosa
# 64     versicolor
# 141      virginca
# 68     versicolor
# 82     versicolor
# 110      virginca
# 12         setosa
# 36         setosa
# 9          setosa
# 19         setosa
# 56     versicolor
# 104      virginca
# 69     versicolor
# 55     versicolor
# 132      virginca
# 29         setosa
# 127      virginca
# 26         setosa
# 128      virginca
# 131      virginca
# 145      virginca
# 108      virginca
# 143      virginca
# 45         setosa
# 30         setosa
# 22         setosa
# 15         setosa
# 65     versicolor
# 11         setosa
# 42         setosa
# 146      virginca
# 51     versicolor
# 27         setosa
# 4          setosa
# 32         setosa
# 142      virginca
# 85     versicolor
# 86     versicolor
# 16         setosa
# 10         setosa
# Name: species, dtype: object
# ...

# %%
print("Actual values:", y_test.values)
print("Predicted values:", predictions) # Changed 'y_pred' to 'predictions'
# Out:
# Actual values: ['versicolor' 'setosa' 'virginca' 'versicolor' 'versicolor' 'setosa'
#  'versicolor' 'virginca' 'versicolor' 'versicolor' 'virginca' 'setosa'
#  'setosa' 'setosa' 'setosa' 'versicolor' 'virginca' 'versicolor'
#  'versicolor' 'virginca' 'setosa' 'virginca' 'setosa' 'virginca'
#  'virginca' 'virginca' 'virginca' 'virginca' 'setosa' 'setosa' 'setosa'
#  'setosa' 'versicolor' 'setosa' 'setosa' 'virginca' 'versicolor' 'setosa'
#  'setosa' 'setosa' 'virginca' 'versicolor' 'versicolor' 'setosa' 'setosa']
# Predicted values: ['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor']

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, predictions))
sns.heatmap(confusion_matrix(y_test, predictions), annot = True, cmap = 'Blues', fmt = 'd')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f7736d71b135> in <cell line: 0>()
#       1 from sklearn.metrics import classification_report, confusion_matrix
# ----> 2 print(classification_report(y_test, predictions))
#       3 sns.heatmap(confusion_matrix(y_test, predictions), annot = True, cmap = 'Blues', fmt = 'd')
#       4 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Assuming 'predictions' from model.predict(X_test) is the correct one
predictions = model.predict(X_test) # Get predictions for the entire test set

print(classification_report(y_test, predictions))
sns.heatmap(confusion_matrix(y_test, predictions), annot=True, cmap='Blues', fmt='d')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#     virginca       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from google.colab import files
uploaded = files.upload

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c3df00f-2b99-4bb9-a3f2-d86a9e907fa7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c3df00f-2b99-4bb9-a3f2-d86a9e907fa7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('salaries.csv')
df
# Out:
#        company                  job     degree  salary_more_then_100k
# 0       google      sales executive  bachelors                      0
# 1       google      sales executive    masters                      0
# 2       google     business manager  bachelors                      1
# 3       google     business manager    masters                      1
# 4       google  computer programmer  bachelors                      0
# 5       google  computer programmer    masters                      1
# 6   abc pharma      sales executive    masters                      0
# 7   abc pharma  computer programmer  bachelors                      0
# 8   abc pharma     business manager  bachelors                      0
# 9   abc pharma     business manager    masters                      1
# 10    facebook      sales executive  bachelors                      1
# 11    facebook      sales executive    masters                      1
# ...

# %%
inputs = df.drop('salary_more_then_100k', axis = 'columns')
target = df['salary_more_then_100k']

# %%
target
# Out:
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     0
# 8     0
# 9     1
# 10    1
# 11    1
# 12    1
# 13    1
# 14    1
# 15    1
# Name: salary_more_then_100k, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_company = LabelEncoder()
le_job = LabelEncoder()
le_degree = LabelEncoder()

# %%
inputs['company_n'] = le_company.fit_transform(inputs['company'])
inputs['job_n'] = le_company.fit_transform(inputs['job'])
inputs['degree_n'] = le_company.fit_transform(inputs['degree'])
inputs.head()
# Out:
#   company                  job     degree  company_n  job_n  degree_n
# 0  google      sales executive  bachelors          2      2         0
# 1  google      sales executive    masters          2      2         1
# 2  google     business manager  bachelors          2      0         0
# 3  google     business manager    masters          2      0         1
# 4  google  computer programmer  bachelors          2      1         0

# %%
inputs_n = inputs.drop(['company', 'job','degree'], axis = 'columns')
inputs_n
# Out:
#     company_n  job_n  degree_n
# 0           2      2         0
# 1           2      2         1
# 2           2      0         0
# 3           2      0         1
# 4           2      1         0
# 5           2      1         1
# 6           0      2         1
# 7           0      1         0
# 8           0      0         0
# 9           0      0         1
# 10          1      2         0
# 11          1      2         1
# 12          1      0         0
# 13          1      0         1
# 14          1      1         0
# 15          1      1         1

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n, target)
# Out:
# 1.0

# %%
model.predict([[2,0,0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model.predict([[2,2,1]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.predict([[1,1,1]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-650faebf-596f-4721-b6c2-22636e29161e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-650faebf-596f-4721-b6c2-22636e29161e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
inputs = df.drop(['Passenger, Name, SibSp, Parch, Ticket, Cabin, Embarked'], axis ='columns' )
inputs_n
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-791bad9e9eb2> in <cell line: 0>()
# ----> 1 inputs = df.drop(['Passenger, Name, SibSp, Parch, Ticket, Cabin, Embarked'], axis ='columns' )
#       2 inputs_n
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
inputs = df.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis='columns')
target = df['Survived'] # Assuming you want inputs_n to be the same as inputs after dropping columns

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_Sex = LabelEncoder()
le_Pclass = LabelEncoder()
le_Age = LabelEncoder()
le_Fare = LabelEncoder()

# %%
inputs['Sex_n'] = le_company.fit_transform(inputs['Sex'])
inputs['Pclass_n'] = le_company.fit_transform(inputs['Pclass'])
inputs['Age_n'] = le_company.fit_transform(inputs['Age'])
inputs['Fare_n'] = le_company.fit_transform(inputs['Fare'])
inputs.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Sex_n  Pclass_n  Age_n  Fare_n
# 0         0       2    1   28    18      1         2     28      18
# 1         1       0    0   51   207      0         0     51     207
# 2         1       2    0   34    41      0         2     34      41
# 3         1       0    0   47   189      0         0     47     189
# 4         0       2    1   47    43      1         2     47      43

# %%
inputs_n = inputs.drop(['Sex','Pclass','Age','Fare'], axis = 'columns')
inputs_n
# Out:
#      Survived  Sex_n  Pclass_n  Age_n  Fare_n
# 0           0      1         2     28      18
# 1           1      0         0     51     207
# 2           1      0         2     34      41
# 3           1      0         0     47     189
# 4           0      1         2     47      43
# ..        ...    ...       ...    ...     ...
# 886         0      1         1     35      85
# 887         1      0         0     24     153
# 888         0      0         2     88     131
# 889         1      1         0     34     153
# 890         0      1         2     42      30
#
# [891 rows x 5 columns]

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(inputs_n, target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n, target)
# Out:
# 1.0

# %%
model.predict([[0,0,51,207]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-f1ce794e6e5f> in <cell line: 0>()
# ----> 1 model.predict([[0,0,51,207]])
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     528         """
#     529         check_is_fitted(self)
# --> 530         X = self._validate_X_predict(X, check_input)
#     531         proba = self.tree_.predict(X)
#     532         n_samples = X.shape[0]
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     487             else:
#     488                 ensure_all_finite = True
# ...

# %%
# Instead of dropping the original columns, keep the encoded ones.
# This ensures the model is trained with the correct number of features.
inputs_n = inputs[['Sex', 'Pclass', 'Age', 'Fare']]

# Now, when making predictions, provide the encoded values for 'Sex', 'Pclass', 'Age', 'Fare'
# For example, if 'Sex' is encoded as 0 for female and 1 for male, 'Pclass' is encoded as 0, 1, 2, and so on:
prediction = model.predict([[0, 1, 30, 75]])  # Replace with appropriate encoded values.
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-ca669c39bac8> in <cell line: 0>()
#       5 # Now, when making predictions, provide the encoded values for 'Sex', 'Pclass', 'Age', 'Fare'
#       6 # For example, if 'Sex' is encoded as 0 for female and 1 for male, 'Pclass' is encoded as 0, 1, 2, and so on:
# ----> 7 prediction = model.predict([[0, 1, 30, 75]])  # Replace with appropriate encoded values.
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     528         """
#     529         check_is_fitted(self)
# --> 530         X = self._validate_X_predict(X, check_input)
# ...

# %%
model.predict([[0,0,51,207]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-f1ce794e6e5f> in <cell line: 0>()
# ----> 1 model.predict([[0,0,51,207]])
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     528         """
#     529         check_is_fitted(self)
# --> 530         X = self._validate_X_predict(X, check_input)
#     531         proba = self.tree_.predict(X)
#     532         n_samples = X.shape[0]
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     487             else:
#     488                 ensure_all_finite = True
# ...

# %%
# In cell ipython-input-33-f1ce794e6e5f:
from sklearn import tree

# Instead of dropping the original columns, keep the encoded ones.
inputs_n = inputs[['Sex_n', 'Pclass_n', 'Age_n', 'Fare_n']]  # Assuming these are your encoded features

model = tree.DecisionTreeClassifier()
model.fit(inputs_n, target)

# ... (rest of your code)

# In cell ipython-input-39-f1ce794e6e5f and ipython-input-40-f1ce794e6e5f:

# Make sure to provide encoded values for all four features during prediction.
# For example:
prediction = model.predict([[0, 1, 30, 75]])  # Replace with appropriate encoded values.
#prediction = model.predict([[0,0,51,207]])  # Assuming these are your encoded values.
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
inputs = df.drop('Survived', axis = 'columns')
target = df['Survived']

# %%
model.predict([[0,0,51,207]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f38b9da1-890f-42c5-875a-0381ea41e8fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f38b9da1-890f-42c5-875a-0381ea41e8fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
label_encoders = {}
encoded_data = mushrooms.data.copy()
for column in mushrooms.data.columns:
  le = LabelEncoder()
  encoded_data[column] = le.fit_transform(mushrooms.data[column])
  label_encoders[column] = le
  X = encoded_data.drop(columns = ['class'])
  y = encoded_data['class']
  decision_tree = DecisionTreeClassifier(random_state = 42)
  decision_tree.fit(X,y)

  feature_importances = pd.DataFrame({
      'Feature': X.columns,
      'Importance': decision_tree.feature_importances_
  }).sort_values(by = 'Importance', ascending = False)
  print(feature_importances)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5b714b9a027a> in <cell line: 0>()
#       3 import pandas as pd
#       4 label_encoders = {}
# ----> 5 encoded_data = mushrooms.data.copy()
#       6 for column in mushrooms.data.columns:
#       7   le = LabelEncoder()
#
# NameError: name 'mushrooms' is not defined

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
import pandas as pd  # Make sure pandas is imported

# Assuming 'df' is your DataFrame from pd.read_csv('mushrooms.csv')
label_encoders = {}
encoded_data = df.copy()  # Use 'df' instead of 'mushrooms'

for column in df.columns:  # Use 'df' for columns as well
  le = LabelEncoder()
  encoded_data[column] = le.fit_transform(df[column])  # Use 'df' for data
  label_encoders[column] = le
  X = encoded_data.drop(columns=['class'])
  y = encoded_data['class']
  decision_tree = DecisionTreeClassifier(random_state=42)
  decision_tree.fit(X, y)

  feature_importances = pd.DataFrame({
      'Feature': X.columns,
      'Importance': decision_tree.feature_importances_
  }).sort_values(by='Importance', ascending=False)
  print(feature_importances)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-458b694e64e1> in <cell line: 0>()
#      14   y = encoded_data['class']
#      15   decision_tree = DecisionTreeClassifier(random_state=42)
# ---> 16   decision_tree.fit(X, y)
#      17
#      18   feature_importances = pd.DataFrame({
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1017         """
#    1018
# -> 1019         super()._fit(
#    1020             X,
#    1021             y,
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
label_encoders = {}
encoded_data = df.copy()  # Use 'df' instead of 'mushrooms'

for column in df.columns:  # Use 'df' for columns as well
  le = LabelEncoder()
  encoded_data[column] = le.fit_transform(df[column])  # Use 'df' for data
  label_encoders[column] = le
  X = encoded_data.drop(columns=['class'])
  y = encoded_data['class']
  decision_tree = DecisionTreeClassifier(random_state=42)
  decision_tree.fit(X, y)

  feature_importances = pd.DataFrame({
      'Feature': X.columns,
      'Importance': decision_tree.feature_importances_
  }).sort_values(by='Importance', ascending=False)
  print(feature_importances)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-afc8017ddbd9> in <cell line: 0>()
#      12   y = encoded_data['class']
#      13   decision_tree = DecisionTreeClassifier(random_state=42)
# ---> 14   decision_tree.fit(X, y)
#      15
#      16   feature_importances = pd.DataFrame({
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1017         """
#    1018
# -> 1019         super()._fit(
#    1020             X,
#    1021             y,
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
import pandas as pd

label_encoders = {}
encoded_data = df.copy()

for column in df.columns:
    le = LabelEncoder()
    encoded_data[column] = le.fit_transform(df[column])
    label_encoders[column] = le

# Move X and y assignments outside the loop
X = encoded_data.drop(columns=['class'])
y = encoded_data['class']

decision_tree = DecisionTreeClassifier(random_state=42)
decision_tree.fit(X, y)

feature_importances = pd.DataFrame({
    'Feature': X.columns,
    'Importance': decision_tree.feature_importances_
}).sort_values(by='Importance', ascending=False)
print(feature_importances)
# Out:
#                      Feature  Importance
# 8                 gill-color    0.341473
# 19         spore-print-color    0.207163
# 20                population    0.176778
# 7                  gill-size    0.116062
# 4                       odor    0.036499
# 21                   habitat    0.029639
# 3                    bruises    0.028572
# 9                stalk-shape    0.025186
# 14    stalk-color-below-ring    0.017071
# 10                stalk-root    0.011624
# 11  stalk-surface-above-ring    0.003698
# 2                  cap-color    0.002972
# 12  stalk-surface-below-ring    0.001946
# 17               ring-number    0.001318
# 1                cap-surface    0.000000
# 13    stalk-color-above-ring    0.000000
# 6               gill-spacing    0.000000
# 15                 veil-type    0.000000
# 16                veil-color    0.000000
# 18                 ring-type    0.000000
# 5            gill-attachment    0.000000
# 0                  cap-shape    0.000000

# %%
import pandas as pd
df = pd.read_csv('mushrooms.csv')

# %%
print(df)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
inputs = inputs.drop(['odor', 'habitat', 'bruises','stalk-shape','stalk-color-below-ring','stalk-root','stalk-surface-above-ring','cap-color','stalk-surface-below-ring','ring-number','cap-surface','stalk-color-above-ring','gill-spacing','veil-type','veil-color','ring-type','gill-attachment','cap-shape'], axis = 'columns')
target = df['class']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f8eac20e9972> in <cell line: 0>()
# ----> 1 inputs = inputs.drop(['odor', 'habitat', 'bruises','stalk-shape','stalk-color-below-ring','stalk-root','stalk-surface-above-ring','cap-color','stalk-surface-below-ring','ring-number','cap-surface','stalk-color-above-ring','gill-spacing','veil-type','veil-color','ring-type','gill-attachment','cap-shape'], axis = 'columns')
#       2 target = df['class']
#
# NameError: name 'inputs' is not defined

# %%
inputs = df.drop(['odor', 'habitat', 'bruises','stalk-shape','stalk-color-below-ring','stalk-root','stalk-surface-above-ring','cap-color','stalk-surface-below-ring','ring-number','cap-surface','stalk-color-above-ring','gill-spacing','veil-type','veil-color','ring-type','gill-attachment','cap-shape'], axis = 'columns')
target = df['class']

# %%
target
# Out:
# 0       p
# 1       e
# 2       e
# 3       p
# 4       e
#        ..
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Out:
#   File "<ipython-input-17-a1195b579bea>", line 5
#     le_gill-size = LabelEncoder()
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
le_gillcolor = LabelEncoder()
le_sporeprintcolor = LabelEncoder()
le_population = LabelEncoder()
le_gillsize = LabelEncoder()

# %%
inputs['gillcolor_n'] = le_company.fit_transform(inputs['Sex'])
inputs['sporeprintcolor_n'] = le_company.fit_transform(inputs['Pclass'])
inputs['population_n'] = le_company.fit_transform(inputs['Age'])
inputs['gillsize_n'] = le_company.fit_transform(inputs['Fare'])
inputs.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-45a50495bc72> in <cell line: 0>()
# ----> 1 inputs['gillcolor_n'] = le_company.fit_transform(inputs['Sex'])
#       2 inputs['sporeprintcolor_n'] = le_company.fit_transform(inputs['Pclass'])
#       3 inputs['population_n'] = le_company.fit_transform(inputs['Age'])
#       4 inputs['gillsize_n'] = le_company.fit_transform(inputs['Fare'])
#       5 inputs.head()
#
# NameError: name 'le_company' is not defined

# %%
inputs['gillcolor_n'] = le_gillcolor.fit_transform(inputs['gill-color'])  # Use le_gillcolor and the 'gill-color' column
inputs['sporeprintcolor_n'] = le_sporeprintcolor.fit_transform(inputs['spore-print-color'])  # Use le_sporeprintcolor and the 'spore-print-color' column
inputs['population_n'] = le_population.fit_transform(inputs['population'])  # Use le_population and the 'population' column
inputs['gillsize_n'] = le_gillsize.fit_transform(inputs['gill-size'])  # Use le_gillsize and the 'gill-size' column
inputs.head()
# Out:
#   class gill-size gill-color spore-print-color population  gillcolor_n  \
# 0     p         n          k                 k          s            4
# 1     e         b          k                 n          n            4
# 2     e         b          n                 n          n            5
# 3     p         n          n                 k          s            5
# 4     e         b          k                 n          a            4
#
#    sporeprintcolor_n  population_n  gillsize_n
# 0                  2             3           1
# 1                  3             2           0
# 2                  3             2           0
# 3                  2             3           1
# 4                  3             0           0

# %%
inputs_n = inputs.drop(['gillsize','gillcolor','sporeprintcolor','population'], axis = 'columns')
inputs_n
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-4a73943ae3d1> in <cell line: 0>()
# ----> 1 inputs_n = inputs.drop(['gillsize','gillcolor','sporeprintcolor','population'], axis = 'columns')
#       2 inputs_n
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
# ...

# %%
inputs_n = inputs.drop(['gill-size','gill-color','spore-print-color','population'], axis = 'columns')
inputs_n
# Out:
#      class  gillcolor_n  sporeprintcolor_n  population_n  gillsize_n
# 0        p            4                  2             3           1
# 1        e            4                  3             2           0
# 2        e            5                  3             2           0
# 3        p            5                  2             3           1
# 4        e            4                  3             0           0
# ...    ...          ...                ...           ...         ...
# 8119     e           11                  0             1           0
# 8120     e           11                  0             4           0
# 8121     e            5                  0             1           0
# 8122     p            0                  7             4           1
# 8123     e           11                  4             1           0
#
# [8124 rows x 5 columns]

# %%
inputs = df.drop('class', axis = 'columns')
target = df['class']

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(inputs_n, target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-4b94cd1d1b39> in <cell line: 0>()
#       1 from sklearn import tree
#       2 model = tree.DecisionTreeClassifier()
# ----> 3 model.fit(inputs_n, target)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1017         """
#    1018
# -> 1019         super()._fit(
#    1020             X,
#    1021             y,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

# Assuming 'df' contains your mushroom data
inputs = df.drop('class', axis='columns')
target = df['class']

# Create and fit LabelEncoders for all categorical columns in 'inputs'
label_encoders = {}
for column in inputs.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    inputs[column] = le.fit_transform(inputs[column])
    label_encoders[column] = le

# Now 'inputs' should contain only numerical data
# You can directly use it for training:
model = tree.DecisionTreeClassifier()
model.fit(inputs, target)

# For predictions, make sure to encode new data using the same LabelEncoders
# For example:
# new_data = {'gill-color': ['brown'], 'spore-print-color': ['black'], ...}
# new_data_encoded = {col: label_encoders[col].transform(new_data[col]) for col in new_data}
# prediction = model.predict(pd.DataFrame([new_data_encoded]))
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs, target)
# Out:
# 1.0

# %%
model.predict([[4,2,3,1]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-3402cc5f567f> in <cell line: 0>()
# ----> 1 model.predict([[4,2,3,1]])
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in predict(self, X, check_input)
#     528         """
#     529         check_is_fitted(self)
# --> 530         X = self._validate_X_predict(X, check_input)
#     531         proba = self.tree_.predict(X)
#     532         n_samples = X.shape[0]
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in _validate_X_predict(self, X, check_input)
#     487             else:
#     488                 ensure_all_finite = True
# --> 489             X = validate_data(
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import tree
import pandas as pd

# Assuming 'df' contains your mushroom data
inputs = df[['gill-color', 'spore-print-color', 'population', 'gill-size']]  # Select only the four features
target = df['class']

# Create and fit LabelEncoders for the selected features
label_encoders = {}
for column in inputs.columns:  # Iterate through the four features
    le = LabelEncoder()
    inputs[column] = le.fit_transform(inputs[column])
    label_encoders[column] = le

# Now 'inputs' contains only the encoded four features
model = tree.DecisionTreeClassifier()
model.fit(inputs, target)

# For predictions, make sure to encode new data using the same LabelEncoders
# For example:
# new_data = {'gill-color': ['brown'], 'spore-print-color': ['black'], 'population': ['scattered'], 'gill-size': ['broad']}
# new_data_encoded = {col: label_encoders[col].transform(new_data[col]) for col in new_data}
# prediction = model.predict(pd.DataFrame([new_data_encoded]))
# Out:
# <ipython-input-30-b504807cd150>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inputs[column] = le.fit_transform(inputs[column])
# <ipython-input-30-b504807cd150>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inputs[column] = le.fit_transform(inputs[column])
# <ipython-input-30-b504807cd150>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
model.score(inputs, target)
# Out:
# 0.982028557360906

# %%
model.predict([[4,2,3,1]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['p'], dtype=object)

# %%
model.predict([[4,3,2,0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['e'], dtype=object)

# %%
model.predict([[4,3,0,1]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['p'], dtype=object)

# %%
model.predict([[11,0,1,0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['e'], dtype=object)
